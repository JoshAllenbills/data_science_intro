# %% [markdown]
# # intro to data science with pokemon
# ***

# %% [markdown]
# ### Arrays

# %%
food = ["Cheese","bread","pastrami","lettuce","tomato"]

# %%
print(food)
# Out:
# ['Cheese', 'bread', 'pastrami', 'lettuce', 'tomato']

# %%
print(food[1])
# Out:
# bread

# %%
sliced_food_list = food[0:3]

# %%
print(sliced_food_list)
# Out:
# ['Cheese', 'bread', 'pastrami']

# %% [markdown]
# ### Import Libraries
# ***

# %%
import pandas as pd
import numpy as py
import seaborn as sb

# %%
print("PANDAS version"+ pd.__version__)
print("NUMPY version" + py.__version__)
print("SEABORN version" + sb.__version__)
# Out:
# PANDAS version2.2.3
# NUMPY version2.1.1
# SEABORN version0.13.2

# %% [markdown]
# ### Loading Data
# ***

# %%
df = pd.read_csv('pokemon.csv')

# %% [markdown]
# ### Displaying full data frames
# ***

# %%
#pd.set_option('dipslay.max_rows',None)

# %%
df.head()
# Out:
#    Per  Nat     Pokemon  HP  Atk  Def  SpA  SpD  Spe  Total  ... Catch  \
# 0  1.0  1.0   Bulbasaur  45   49   49   65   65   45    318  ...    45
# 1  2.0  2.0     Ivysaur  60   62   63   80   80   60    405  ...    45
# 2  3.0  3.0    Venusaur  80   82   83  100  100   80    525  ...    45
# 3  4.0  4.0  Charmander  39   52   43   60   50   65    309  ...    45
# 4  5.0  5.0  Charmeleon  58   64   58   80   65   80    405  ...    45
#
#        EXP  Evolve Per.1 Nat.1    Joh Hoe  Sin  Un   Pokemon.1
# 0  1059860     NaN   1.0   1.0  226.0 NaN  NaN NaN   Bulbasaur
# 1  1059860  Lv. 16   2.0   2.0  227.0 NaN  NaN NaN     Ivysaur
# 2  1059860  Lv. 32   3.0   3.0  228.0 NaN  NaN NaN    Venusaur
# 3  1059860     NaN   4.0   4.0  229.0 NaN  NaN NaN  Charmander
# 4  1059860  Lv. 16   5.0   5.0  230.0 NaN  NaN NaN  Charmeleon
#
# [5 rows x 35 columns]

# %%
df.head(150)
# Out:
#        Per    Nat     Pokemon   HP  Atk  Def  SpA  SpD  Spe  Total  ... Catch  \
# 0      1.0    1.0   Bulbasaur   45   49   49   65   65   45    318  ...    45
# 1      2.0    2.0     Ivysaur   60   62   63   80   80   60    405  ...    45
# 2      3.0    3.0    Venusaur   80   82   83  100  100   80    525  ...    45
# 3      4.0    4.0  Charmander   39   52   43   60   50   65    309  ...    45
# 4      5.0    5.0  Charmeleon   58   64   58   80   65   80    405  ...    45
# ..     ...    ...         ...  ...  ...  ...  ...  ...  ...    ...  ...   ...
# 145  177.0  146.0     Moltres   90  100   90  125   85   90    580  ...     3
# 146  178.0  147.0     Dratini   41   64   45   50   50   50    300  ...    45
# 147  179.0  148.0   Dragonair   61   84   65   70   70   70    420  ...    45
# 148  180.0  149.0   Dragonite   91  134   95  100  100   80    600  ...    45
# 149  181.0  150.0      Mewtwo  106  110   90  154   90  130    680  ...     3
#
#          EXP  Evolve  Per.1  Nat.1    Joh Hoe  Sin  Un   Pokemon.1
# 0    1059860     NaN    1.0    1.0  226.0 NaN  NaN NaN   Bulbasaur
# 1    1059860  Lv. 16    2.0    2.0  227.0 NaN  NaN NaN     Ivysaur
# 2    1059860  Lv. 32    3.0    3.0  228.0 NaN  NaN NaN    Venusaur
# 3    1059860     NaN    4.0    4.0  229.0 NaN  NaN NaN  Charmander
# 4    1059860  Lv. 16    5.0    5.0  230.0 NaN  NaN NaN  Charmeleon
# ..       ...     ...    ...    ...    ...  ..  ...  ..         ...
# 145  1250000       N  177.0  146.0  237.0 NaN  NaN NaN     Moltres
# 146  1250000     NaN  178.0  147.0  241.0 NaN  NaN NaN     Dratini
# 147  1250000  Lv. 30  179.0  148.0  242.0 NaN  NaN NaN   Dragonair
# 148  1250000  Lv. 55  180.0  149.0  243.0 NaN  NaN NaN   Dragonite
# 149  1250000       N  181.0  150.0  249.0 NaN  NaN NaN      Mewtwo
#
# [150 rows x 35 columns]

# %% [markdown]
# ### Accessing columns
# ***

# %%
pokemon_column = df.Pokemon

# %% [markdown]
# 'Bulbosar'

# %%
df.Pokemon[0:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Pokemon, dtype: object
